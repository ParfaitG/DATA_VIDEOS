# %% [markdown]
# # Nested Structures for Data Analytics in Pandas
#
# <div style="width:200px"><img src="images/python_xml_json.png" alt="sql analytics icon" width="200px" style="text-align:left;"/></div>
# <br/>
#
# ## Popular Structured Data File Formats
#
# <ul style="font-size:20px;line-height:24px">
#     <li>Text delimited files: comma-separated, tab-delimited, pipe-delimited, etc.</li>
#     <li>Nested files: XML, JSON, HTML, YAML, etc.</li>
#     <li>Binary files: Excel spreadsheets, Stata .dta, Python pickles, etc.</li>
# </ul>
# <br/>
#
#
# <hr style="border: 0.5px solid #E0E0E0;"/>
#
# <h2>XML Data</h2>
#
# <span style="font-size:20px;line-height:24px;">(E<b>x</b>tensible <b>M</b>arkup <b>L</b>anguage)</span>
#
# <ul style="font-size:20px;line-height:24px">
#     <li>Tree-like, markup nested structures (i.e., root, nodes)</li>
#     <li>Decades-long industry standards and specifications</li>
#     <ul style="font-size:18px;line-height:22px"><li>E.g., KML, MathML, MusicXML, RDF, RSS, SVG</li></ul>
#     <li>Used in APIs, archives, data dumps, metadata</li>
# </ul>
#
# <hr style="border: 0.5px solid #E0E0E0;"/>

# %% [markdown]
# ## Example Data:
#
# ## City of Chicago: CTA Monthly L Rides
# <span style="font-size: 18px"><a href="https://data.cityofchicago.org/Transportation/CTA-Ridership-L-Station-Entries-Monthly-Day-Type-A/t2rn-p8d7">https://data.cityofchicago.org/Transportation/CTA-Ridership-L-Station-Entries-Monthly-Day-Type-A/t2rn-p8d7</a></span>

# %%
# %%html
# <style>.prompt{width: 100px; min-width: 0; visibility: collapse}</style>
# Out:
# <style>.prompt{width: 100px; min-width: 0; visibility: collapse}</style>

# %%
import xml.etree.ElementTree as xet   # BUILT-IN MODULE
import lxml.etree as lxet             # THIRD-PARTY MODULE

import pandas as pd

# %%
doc = xet.parse("data/cta_monthly_l_rides_preview.xml")
doc2 = lxet.parse("data/cta_monthly_l_rides_preview.xml")

print(xet.tostring(doc.getroot()).decode("utf-8"))
# Out:
# <response>
#   <row>
#     <row _id="row-fwjy-9q5k-ps6p" _uuid="00000000-0000-0000-5FAB-5CAB5D21E10C" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-fwjy-9q5k-ps6p">
#       <station_id>40900</station_id>
#       <stationame>Howard</stationame>
#       <month_beginning>2001-01-01T00:00:00</month_beginning>
#       <avg_weekday_rides>6233.9</avg_weekday_rides>
#       <avg_saturday_rides>3814.5</avg_saturday_rides>
#       <avg_sunday_holiday_rides>2408.6</avg_sunday_holiday_rides>
#       <monthtotal>164447</monthtotal>
#     </row>
#     <row _id="row-nyyd~hctf_nrwa" _uuid="00000000-0000-0000-6DE8-BA4BB25FC36E" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-nyyd~hctf_nrwa">
#       <station_id>41190</station_id>
#       <stationame>Jarvis</stationame>
#       <month_beginning>2001-01-01T00:00:00</month_beginning>
#       <avg_weekday_rides>1489.1</avg_weekday_rides>
#       <avg_saturday_rides>1054</avg_saturday_rides>
#       <avg_sunday_holiday_rides>718</avg_sunday_holiday_rides>
#       <monthtotal>40567</monthtotal>
#     </row>
#     <row _id="row-t6pr.n6ds.4am9" _uuid="00000000-0000-0000-2191-71EC625EDF2F" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-t6pr.n6ds.4am9">
#       <station_id>40100</station_id>
#       <stationame>Morse</stationame>
#       <month_beginning>2001-01-01T00:00:00</month_beginning>
#       <avg_weekday_rides>4412.5</avg_weekday_rides>
#       <avg_saturday_rides>3064.5</avg_saturday_rides>
#       <avg_sunday_holiday_rides>2087.8</avg_sunday_holiday_rides>
#       <monthtotal>119772</monthtotal>
#     </row>
#     <row _id="row-cjyk~sup7-huut" _uuid="00000000-0000-0000-0AE6-ACE513A0342D" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-cjyk~sup7-huut">
#       <station_id>41300</station_id>
#       <stationame>Loyola</stationame>
#       <month_beginning>2001-01-01T00:00:00</month_beginning>
#       <avg_weekday_rides>4664.5</avg_weekday_rides>
#       <avg_saturday_rides>3156</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1952.8</avg_sunday_holiday_rides>
#       <monthtotal>125008</monthtotal>
#     </row>
#     <row _id="row-8ikx~cq3f.zwm2" _uuid="00000000-0000-0000-5665-E0B11642D467" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-8ikx~cq3f.zwm2">
#       <station_id>40760</station_id>
#       <stationame>Granville</stationame>
#       <month_beginning>2001-01-01T00:00:00</month_beginning>
#       <avg_weekday_rides>3109.8</avg_weekday_rides>
#       <avg_saturday_rides>2126</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1453.8</avg_sunday_holiday_rides>
#       <monthtotal>84189</monthtotal>
#     </row>
#     <row _id="row-vvtf_7vrm-97xy" _uuid="00000000-0000-0000-5736-C996BCE35489" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-vvtf_7vrm-97xy">
#       <station_id>40850</station_id>
#       <stationame>Library</stationame>
#       <month_beginning>2020-09-01T00:00:00</month_beginning>
#       <avg_weekday_rides>864.2</avg_weekday_rides>
#       <avg_saturday_rides>534</avg_saturday_rides>
#       <avg_sunday_holiday_rides>417.2</avg_sunday_holiday_rides>
#       <monthtotal>22370</monthtotal>
#     </row>
#     <row _id="row-n9ei.vu5v.yd52" _uuid="00000000-0000-0000-4734-5E409BEA7F70" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-n9ei.vu5v.yd52">
#       <station_id>40680</station_id>
#       <stationame>Adams/Wabash</stationame>
#       <month_beginning>2020-09-01T00:00:00</month_beginning>
#       <avg_weekday_rides>1332.3</avg_weekday_rides>
#       <avg_saturday_rides>791.8</avg_saturday_rides>
#       <avg_sunday_holiday_rides>601.6</avg_sunday_holiday_rides>
#       <monthtotal>34154</monthtotal>
#     </row>
#     <row _id="row-h278_29y8-vcs5" _uuid="00000000-0000-0000-2D6E-542239E417F5" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-h278_29y8-vcs5">
#       <station_id>41700</station_id>
#       <stationame>Washington/Wabash</stationame>
#       <month_beginning>2020-09-01T00:00:00</month_beginning>
#       <avg_weekday_rides>2707.4</avg_weekday_rides>
#       <avg_saturday_rides>1909.8</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1438.6</avg_sunday_holiday_rides>
#       <monthtotal>71688</monthtotal>
#     </row>
#     <row _id="row-icuu~a5em_e9n4" _uuid="00000000-0000-0000-368B-C636EBE912C2" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-icuu~a5em_e9n4">
#       <station_id>40260</station_id>
#       <stationame>State/Lake</stationame>
#       <month_beginning>2020-09-01T00:00:00</month_beginning>
#       <avg_weekday_rides>2410</avg_weekday_rides>
#       <avg_saturday_rides>2042.3</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1660.6</avg_sunday_holiday_rides>
#       <monthtotal>67083</monthtotal>
#     </row>
#     <row _id="row-na7a~6yct-k8fv" _uuid="00000000-0000-0000-965D-B7B17499AB88" _position="0" _address="https://data.cityofchicago.org/resource/t2rn-p8d7/row-na7a~6yct-k8fv">
#       <station_id>40380</station_id>
#       <stationame>Clark/Lake</stationame>
#       <month_beginning>2020-09-01T00:00:00</month_beginning>
#       <avg_weekday_rides>2949.6</avg_weekday_rides>
#       <avg_saturday_rides>1657</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1453.8</avg_sunday_holiday_rides>
#       <monthtotal>75839</monthtotal>
#     </row>
#   </row>
# </response>

# %% [markdown]
# ### <strike><code>pandas.read_xml()</code></strike>

# %%
# df = pd.read_xml("data/cta_monthly_l_rides_preview.xml")        # NOT AVAILABLE YET

# %% [markdown]
# <br/>
#
# <h3>Merge Dictionaries in Nested List/Dict Comprehension</h3>
#
# <h3><code>[{...}] + pandas.DataFrame()</code></h3>

# %%
data_dict = [{**{row.tag:row.text for row in rows.findall('*')}, **rows.attrib}
                 for rows in doc.findall('.//row/row')]

df = pd.DataFrame(data_dict)

df
# Out:
#   station_id         stationame      month_beginning avg_weekday_rides  \
# 0      40900             Howard  2001-01-01T00:00:00            6233.9
# 1      41190             Jarvis  2001-01-01T00:00:00            1489.1
# 2      40100              Morse  2001-01-01T00:00:00            4412.5
# 3      41300             Loyola  2001-01-01T00:00:00            4664.5
# 4      40760          Granville  2001-01-01T00:00:00            3109.8
# 5      40850            Library  2020-09-01T00:00:00             864.2
# 6      40680       Adams/Wabash  2020-09-01T00:00:00            1332.3
# 7      41700  Washington/Wabash  2020-09-01T00:00:00            2707.4
# 8      40260         State/Lake  2020-09-01T00:00:00              2410
# 9      40380         Clark/Lake  2020-09-01T00:00:00            2949.6
#
#   avg_saturday_rides avg_sunday_holiday_rides monthtotal                 _id  \
# 0             3814.5                   2408.6     164447  row-fwjy-9q5k-ps6p
# 1               1054                      718      40567  row-nyyd~hctf_nrwa
# 2             3064.5                   2087.8     119772  row-t6pr.n6ds.4am9
# 3               3156                   1952.8     125008  row-cjyk~sup7-huut
# 4               2126                   1453.8      84189  row-8ikx~cq3f.zwm2
# 5                534                    417.2      22370  row-vvtf_7vrm-97xy
# 6              791.8                    601.6      34154  row-n9ei.vu5v.yd52
# 7             1909.8                   1438.6      71688  row-h278_29y8-vcs5
# 8             2042.3                   1660.6      67083  row-icuu~a5em_e9n4
# 9               1657                   1453.8      75839  row-na7a~6yct-k8fv
#
#                                   _uuid _position  \
# 0  00000000-0000-0000-5FAB-5CAB5D21E10C         0
# 1  00000000-0000-0000-6DE8-BA4BB25FC36E         0
# 2  00000000-0000-0000-2191-71EC625EDF2F         0
# 3  00000000-0000-0000-0AE6-ACE513A0342D         0
# 4  00000000-0000-0000-5665-E0B11642D467         0
# 5  00000000-0000-0000-5736-C996BCE35489         0
# 6  00000000-0000-0000-4734-5E409BEA7F70         0
# 7  00000000-0000-0000-2D6E-542239E417F5         0
# 8  00000000-0000-0000-368B-C636EBE912C2         0
# 9  00000000-0000-0000-965D-B7B17499AB88         0
#
#                                             _address
# 0  https://data.cityofchicago.org/resource/t2rn-p...
# 1  https://data.cityofchicago.org/resource/t2rn-p...
# 2  https://data.cityofchicago.org/resource/t2rn-p...
# 3  https://data.cityofchicago.org/resource/t2rn-p...
# 4  https://data.cityofchicago.org/resource/t2rn-p...
# 5  https://data.cityofchicago.org/resource/t2rn-p...
# 6  https://data.cityofchicago.org/resource/t2rn-p...
# 7  https://data.cityofchicago.org/resource/t2rn-p...
# 8  https://data.cityofchicago.org/resource/t2rn-p...
# 9  https://data.cityofchicago.org/resource/t2rn-p...

# %% [markdown]
# ## XPath
# <span style="font-size:20px">(Query language to search/retrieve nodes within XML documents)</span>

# %%
doc2 = lxet.parse("data/cta_monthly_l_rides.xml")

data_dict = [{row.tag:row.text for row in rows.xpath('*')} 
                 for rows in doc2.xpath(".//row/row[stationame='Midway Airport' and "
                                        "           avg_weekday_rides < 3000 ]")]

df2 = pd.DataFrame(data_dict)
             
df2
# Out:
#   station_id      stationame      month_beginning avg_weekday_rides  \
# 0      40930  Midway Airport  2020-04-01T00:00:00               982
# 1      40930  Midway Airport  2020-05-01T00:00:00            1030.7
# 2      40930  Midway Airport  2020-06-01T00:00:00            1413.8
# 3      40930  Midway Airport  2020-07-01T00:00:00            2022.7
# 4      40930  Midway Airport  2020-08-01T00:00:00            2002.3
# 5      40930  Midway Airport  2020-09-01T00:00:00            2162.7
#
#   avg_saturday_rides avg_sunday_holiday_rides monthtotal
# 0              561.5                    430.5      25571
# 1                648                    452.7      26570
# 2              930.8                    805.3      38047
# 3             1149.8                   1132.8      54763
# 4             1245.6                   1047.6      53515
# 5             1315.5                   1086.8      56113

# %% [markdown]
# ## Nested XML

# %%
doc = xet.parse("data/cta_monthly_l_rides_nested.xml")
doc2 = lxet.parse("data/cta_monthly_l_rides_nested.xml")

print(xet.tostring(doc.getroot()).decode("utf-8"))
# Out:
# <response>
#   <row>
#     <station id="40900" name="Howard" />
#     <month>2001-01-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>6233.9</avg_weekday_rides>
#       <avg_saturday_rides>3814.5</avg_saturday_rides>
#       <avg_sunday_holiday_rides>2408.6</avg_sunday_holiday_rides>
#     </rides>
#   </row>
#   <row>
#     <station id="41190" name="Jarvis" />
#     <month>2001-01-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>1489.1</avg_weekday_rides>
#       <avg_saturday_rides>1054</avg_saturday_rides>
#       <avg_sunday_holiday_rides>718</avg_sunday_holiday_rides>
#     </rides>
#   </row>
#   <row>
#     <station id="40100" name="Morse" />
#     <month>2001-01-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>4412.5</avg_weekday_rides>
#       <avg_saturday_rides>3064.5</avg_saturday_rides>
#       <avg_sunday_holiday_rides>2087.8</avg_sunday_holiday_rides>
#     </rides>
#   </row>
#   <row>
#     <station id="41300" name="Loyola" />
#     <month>2001-01-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>4664.5</avg_weekday_rides>
#       <avg_saturday_rides>3156</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1952.8</avg_sunday_holiday_rides>
#     </rides>
#   </row>
#   <row>
#     <station id="40760" name="Granville" />
#     <month>2001-01-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>3109.8</avg_weekday_rides>
#       <avg_saturday_rides>2126</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1453.8</avg_sunday_holiday_rides>
#     </rides>
#   </row>
#   <row>
#     <station id="40850" name="Library" />
#     <month>2020-09-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>864.2</avg_weekday_rides>
#       <avg_saturday_rides>534</avg_saturday_rides>
#       <avg_sunday_holiday_rides>417.2</avg_sunday_holiday_rides>
#     </rides>
#   </row>
#   <row>
#     <station id="40680" name="Adams/Wabash" />
#     <month>2020-09-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>1332.3</avg_weekday_rides>
#       <avg_saturday_rides>791.8</avg_saturday_rides>
#       <avg_sunday_holiday_rides>601.6</avg_sunday_holiday_rides>
#     </rides>
#   </row>
#   <row>
#     <station id="41700" name="Washington/Wabash" />
#     <month>2020-09-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>2707.4</avg_weekday_rides>
#       <avg_saturday_rides>1909.8</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1438.6</avg_sunday_holiday_rides>
#     </rides>
#   </row>
#   <row>
#     <station id="40260" name="State/Lake" />
#     <month>2020-09-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>2410</avg_weekday_rides>
#       <avg_saturday_rides>2042.3</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1660.6</avg_sunday_holiday_rides>
#     </rides>
#   </row>
#   <row>
#     <station id="40380" name="Clark/Lake" />
#     <month>2020-09-01T00:00:00</month>
#     <rides>
#       <avg_weekday_rides>2949.6</avg_weekday_rides>
#       <avg_saturday_rides>1657</avg_saturday_rides>
#       <avg_sunday_holiday_rides>1453.8</avg_sunday_holiday_rides>
#     </rides>
#   </row>
# </response>

# %% [markdown]
# ## Merge Dictionaries in Nested List/Dict Comprehension
#
# <h3><code>[{...}] + pandas.DataFrame()</code></h3>

# %%
data_dict = [{**{'station_id':rows.find('station').attrib['id'], 
                 'station_name':rows.find('station').attrib['name']}, 
              **{'month':rows.find('month').text}, 
              **{r.tag:r.text for r in rows.findall('rides/*')}}
                       for rows in doc.findall('.//row')]

df = pd.DataFrame(data_dict)
             
df
# Out:
#   station_id       station_name                month avg_weekday_rides  \
# 0      40900             Howard  2001-01-01T00:00:00            6233.9
# 1      41190             Jarvis  2001-01-01T00:00:00            1489.1
# 2      40100              Morse  2001-01-01T00:00:00            4412.5
# 3      41300             Loyola  2001-01-01T00:00:00            4664.5
# 4      40760          Granville  2001-01-01T00:00:00            3109.8
# 5      40850            Library  2020-09-01T00:00:00             864.2
# 6      40680       Adams/Wabash  2020-09-01T00:00:00            1332.3
# 7      41700  Washington/Wabash  2020-09-01T00:00:00            2707.4
# 8      40260         State/Lake  2020-09-01T00:00:00              2410
# 9      40380         Clark/Lake  2020-09-01T00:00:00            2949.6
#
#   avg_saturday_rides avg_sunday_holiday_rides
# 0             3814.5                   2408.6
# 1               1054                      718
# 2             3064.5                   2087.8
# 3               3156                   1952.8
# 4               2126                   1453.8
# 5                534                    417.2
# 6              791.8                    601.6
# 7             1909.8                   1438.6
# 8             2042.3                   1660.6
# 9               1657                   1453.8

# %% [markdown]
# ## XSLT
# <span style="font-size:20px">(Script language to transform XML documents)</span>

# %%
xsl_str = """<xsl:stylesheet version="1.0" xmlns:xsl="http://www.w3.org/1999/XSL/Transform">
                <xsl:output method="xml" omit-xml-declaration="yes" indent="yes"/>
                <xsl:strip-space elements="*"/>

                <xsl:template match="/response">
                 <xsl:copy>
                   <xsl:apply-templates select="row"/>
                 </xsl:copy>
                </xsl:template>
            
                <xsl:template match="row">
                 <xsl:copy>
                   <station_id><xsl:value-of select="station/@id"/></station_id>
                   <station_name><xsl:value-of select="station/@name"/></station_name>
                   <xsl:copy-of select="month|rides/*"/>
                 </xsl:copy>
                </xsl:template>        

            </xsl:stylesheet>
          """

xsl = lxet.fromstring(xsl_str)
transformer = lxet.XSLT(xsl)

flat_doc = transformer(doc2)

print(flat_doc)
# Out:
# <response>
#   <row>
#     <station_id>40900</station_id>
#     <station_name>Howard</station_name>
#     <month>2001-01-01T00:00:00</month>
#     <avg_weekday_rides>6233.9</avg_weekday_rides>
#     <avg_saturday_rides>3814.5</avg_saturday_rides>
#     <avg_sunday_holiday_rides>2408.6</avg_sunday_holiday_rides>
#   </row>
#   <row>
#     <station_id>41190</station_id>
#     <station_name>Jarvis</station_name>
#     <month>2001-01-01T00:00:00</month>
#     <avg_weekday_rides>1489.1</avg_weekday_rides>
#     <avg_saturday_rides>1054</avg_saturday_rides>
#     <avg_sunday_holiday_rides>718</avg_sunday_holiday_rides>
#   </row>
#   <row>
#     <station_id>40100</station_id>
#     <station_name>Morse</station_name>
#     <month>2001-01-01T00:00:00</month>
#     <avg_weekday_rides>4412.5</avg_weekday_rides>
#     <avg_saturday_rides>3064.5</avg_saturday_rides>
#     <avg_sunday_holiday_rides>2087.8</avg_sunday_holiday_rides>
#   </row>
#   <row>
#     <station_id>41300</station_id>
#     <station_name>Loyola</station_name>
#     <month>2001-01-01T00:00:00</month>
#     <avg_weekday_rides>4664.5</avg_weekday_rides>
#     <avg_saturday_rides>3156</avg_saturday_rides>
#     <avg_sunday_holiday_rides>1952.8</avg_sunday_holiday_rides>
#   </row>
#   <row>
#     <station_id>40760</station_id>
#     <station_name>Granville</station_name>
#     <month>2001-01-01T00:00:00</month>
#     <avg_weekday_rides>3109.8</avg_weekday_rides>
#     <avg_saturday_rides>2126</avg_saturday_rides>
#     <avg_sunday_holiday_rides>1453.8</avg_sunday_holiday_rides>
#   </row>
#   <row>
#     <station_id>40850</station_id>
#     <station_name>Library</station_name>
#     <month>2020-09-01T00:00:00</month>
#     <avg_weekday_rides>864.2</avg_weekday_rides>
#     <avg_saturday_rides>534</avg_saturday_rides>
#     <avg_sunday_holiday_rides>417.2</avg_sunday_holiday_rides>
#   </row>
#   <row>
#     <station_id>40680</station_id>
#     <station_name>Adams/Wabash</station_name>
#     <month>2020-09-01T00:00:00</month>
#     <avg_weekday_rides>1332.3</avg_weekday_rides>
#     <avg_saturday_rides>791.8</avg_saturday_rides>
#     <avg_sunday_holiday_rides>601.6</avg_sunday_holiday_rides>
#   </row>
#   <row>
#     <station_id>41700</station_id>
#     <station_name>Washington/Wabash</station_name>
#     <month>2020-09-01T00:00:00</month>
#     <avg_weekday_rides>2707.4</avg_weekday_rides>
#     <avg_saturday_rides>1909.8</avg_saturday_rides>
#     <avg_sunday_holiday_rides>1438.6</avg_sunday_holiday_rides>
#   </row>
#   <row>
#     <station_id>40260</station_id>
#     <station_name>State/Lake</station_name>
#     <month>2020-09-01T00:00:00</month>
#     <avg_weekday_rides>2410</avg_weekday_rides>
#     <avg_saturday_rides>2042.3</avg_saturday_rides>
#     <avg_sunday_holiday_rides>1660.6</avg_sunday_holiday_rides>
#   </row>
#   <row>
#     <station_id>40380</station_id>
#     <station_name>Clark/Lake</station_name>
#     <month>2020-09-01T00:00:00</month>
#     <avg_weekday_rides>2949.6</avg_weekday_rides>
#     <avg_saturday_rides>1657</avg_saturday_rides>
#     <avg_sunday_holiday_rides>1453.8</avg_sunday_holiday_rides>
#   </row>
# </response>

# %% [markdown]
# <hr style="border: 0.5px solid #E0E0E0;"/>
#
#
# ## JSON Data
# <span style="font-size:20px;">(<b>J</b>ava <b>S</b>cript <b>O</b>bject <b>N</b>otation)</span>
#
# <ul style="font-size:20px;line-height:24px">
#     <li>Mapping key-value nested data structure</li>
#     <li>Emerging web/application data format</li>
#     <li>Less restrictive without markup rules</li>
# </ul>

# %%
import json       # BUILT-IN MODULE

# %%
with open('data/cta_monthly_l_rides_preview.json') as f:    
    data = f.read()
    
print(data)
# Out:
# [
#   {
#     "station_id": "40900",
#     "stationame": "Howard",
#     "month_beginning": "2001-01-01T00:00:00",
#     "avg_weekday_rides": "6233.9",
#     "avg_saturday_rides": "3814.5",
#     "avg_sunday_holiday_rides": "2408.6",
#     "monthtotal": "164447"
#   },
#   {
#     "station_id": "41190",
#     "stationame": "Jarvis",
#     "month_beginning": "2001-01-01T00:00:00",
#     "avg_weekday_rides": "1489.1",
#     "avg_saturday_rides": "1054",
#     "avg_sunday_holiday_rides": "718",
#     "monthtotal": "40567"
#   },
#   {
#     "station_id": "40100",
#     "stationame": "Morse",
#     "month_beginning": "2001-01-01T00:00:00",
#     "avg_weekday_rides": "4412.5",
#     "avg_saturday_rides": "3064.5",
#     "avg_sunday_holiday_rides": "2087.8",
#     "monthtotal": "119772"
#   },
#   {
#     "station_id": "41300",
#     "stationame": "Loyola",
#     "month_beginning": "2001-01-01T00:00:00",
#     "avg_weekday_rides": "4664.5",
#     "avg_saturday_rides": "3156",
#     "avg_sunday_holiday_rides": "1952.8",
#     "monthtotal": "125008"
#   },
#   {
#     "station_id": "40760",
#     "stationame": "Granville",
#     "month_beginning": "2001-01-01T00:00:00",
#     "avg_weekday_rides": "3109.8",
#     "avg_saturday_rides": "2126",
#     "avg_sunday_holiday_rides": "1453.8",
#     "monthtotal": "84189"
#   },
#   {
#     "station_id": "40850",
#     "stationame": "Library",
#     "month_beginning": "2020-09-01T00:00:00",
#     "avg_weekday_rides": "864.2",
#     "avg_saturday_rides": "534",
#     "avg_sunday_holiday_rides": "417.2",
#     "monthtotal": "22370"
#   },
#   {
#     "station_id": "40680",
#     "stationame": "Adams/Wabash",
#     "month_beginning": "2020-09-01T00:00:00",
#     "avg_weekday_rides": "1332.3",
#     "avg_saturday_rides": "791.8",
#     "avg_sunday_holiday_rides": "601.6",
#     "monthtotal": "34154"
#   },
#   {
#     "station_id": "41700",
#     "stationame": "Washington/Wabash",
#     "month_beginning": "2020-09-01T00:00:00",
#     "avg_weekday_rides": "2707.4",
#     "avg_saturday_rides": "1909.8",
#     "avg_sunday_holiday_rides": "1438.6",
#     "monthtotal": "71688"
#   },
#   {
#     "station_id": "40260",
#     "stationame": "State/Lake",
#     "month_beginning": "2020-09-01T00:00:00",
#     "avg_weekday_rides": "2410",
#     "avg_saturday_rides": "2042.3",
#     "avg_sunday_holiday_rides": "1660.6",
#     "monthtotal": "67083"
#   },
#   {
#     "station_id": "40380",
#     "stationame": "Clark/Lake",
#     "month_beginning": "2020-09-01T00:00:00",
#     "avg_weekday_rides": "2949.6",
#     "avg_saturday_rides": "1657",
#     "avg_sunday_holiday_rides": "1453.8",
#     "monthtotal": "75839"
#   }
# ]

# %% [markdown]
# <h3><code>pandas.read_json()</code></h3>

# %%
df = pd.read_json('data/cta_monthly_l_rides_preview.json')

df
# Out:
#    station_id         stationame      month_beginning  avg_weekday_rides  \
# 0       40900             Howard  2001-01-01T00:00:00             6233.9
# 1       41190             Jarvis  2001-01-01T00:00:00             1489.1
# 2       40100              Morse  2001-01-01T00:00:00             4412.5
# 3       41300             Loyola  2001-01-01T00:00:00             4664.5
# 4       40760          Granville  2001-01-01T00:00:00             3109.8
# 5       40850            Library  2020-09-01T00:00:00              864.2
# 6       40680       Adams/Wabash  2020-09-01T00:00:00             1332.3
# 7       41700  Washington/Wabash  2020-09-01T00:00:00             2707.4
# 8       40260         State/Lake  2020-09-01T00:00:00             2410.0
# 9       40380         Clark/Lake  2020-09-01T00:00:00             2949.6
#
#    avg_saturday_rides  avg_sunday_holiday_rides  monthtotal
# 0              3814.5                    2408.6      164447
# 1              1054.0                     718.0       40567
# 2              3064.5                    2087.8      119772
# 3              3156.0                    1952.8      125008
# 4              2126.0                    1453.8       84189
# 5               534.0                     417.2       22370
# 6               791.8                     601.6       34154
# 7              1909.8                    1438.6       71688
# 8              2042.3                    1660.6       67083
# 9              1657.0                    1453.8       75839

# %% [markdown]
# ## Nested JSON

# %%
with open('data/cta_monthly_l_rides_nested.json') as f:    
    data = f.read()
    
print(data)
# Out:
# [
#   {
#     "station": {
#       "station_id": "40900",
#       "stationame": "Howard"
#     },
#     "month": "2001-01-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "6233.9",
#       "avg_saturday_rides": "3814.5",
#       "avg_sunday_holiday_rides": "2408.6"
#     }
#   },
#   {
#     "station": {
#       "station_id": "41190",
#       "stationame": "Jarvis"
#     },
#     "month": "2001-01-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "1489.1",
#       "avg_saturday_rides": "1054",
#       "avg_sunday_holiday_rides": "718"
#     }
#   },
#   {
#     "station": {
#       "station_id": "40100",
#       "stationame": "Morse"
#     },
#     "month": "2001-01-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "4412.5",
#       "avg_saturday_rides": "3064.5",
#       "avg_sunday_holiday_rides": "2087.8"
#     }
#   },
#   {
#     "station": {
#       "station_id": "41300",
#       "stationame": "Loyola"
#     },
#     "month": "2001-01-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "4664.5",
#       "avg_saturday_rides": "3156",
#       "avg_sunday_holiday_rides": "1952.8"
#     }
#   },
#   {
#     "station": {
#       "station_id": "40760",
#       "stationame": "Granville"
#     },
#     "month": "2001-01-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "3109.8",
#       "avg_saturday_rides": "2126",
#       "avg_sunday_holiday_rides": "1453.8"
#     }
#   },
#   {
#     "station": {
#       "station_id": "40850",
#       "stationame": "Library"
#     },
#     "month": "2020-09-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "864.2",
#       "avg_saturday_rides": "534",
#       "avg_sunday_holiday_rides": "417.2"
#     }
#   },
#   {
#     "station": {
#       "station_id": "40680",
#       "stationame": "Adams/Wabash"
#     },
#     "month": "2020-09-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "1332.3",
#       "avg_saturday_rides": "791.8",
#       "avg_sunday_holiday_rides": "601.6"
#     }
#   },
#   {
#     "station": {
#       "station_id": "41700",
#       "stationame": "Washington/Wabash"
#     },
#     "month": "2020-09-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "2707.4",
#       "avg_saturday_rides": "1909.8",
#       "avg_sunday_holiday_rides": "1438.6"
#     }
#   },
#   {
#     "station": {
#       "station_id": "40260",
#       "stationame": "State/Lake"
#     },
#     "month": "2020-09-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "2410",
#       "avg_saturday_rides": "2042.3",
#       "avg_sunday_holiday_rides": "1660.6"
#     }
#   },
#   {
#     "station": {
#       "station_id": "40380",
#       "stationame": "Clark/Lake"
#     },
#     "month": "2020-09-01T00:00:00",
#     "rides": {
#       "avg_weekday_rides": "2949.6",
#       "avg_saturday_rides": "1657",
#       "avg_sunday_holiday_rides": "1453.8"
#     }
#   }
# ]

# %%
chi_month_rides_df = pd.read_json('data/cta_monthly_l_rides_nested.json')

chi_month_rides_df
# Out:
#                                              station                month  \
# 0    {'station_id': '40900', 'stationame': 'Howard'}  2001-01-01T00:00:00
# 1    {'station_id': '41190', 'stationame': 'Jarvis'}  2001-01-01T00:00:00
# 2     {'station_id': '40100', 'stationame': 'Morse'}  2001-01-01T00:00:00
# 3    {'station_id': '41300', 'stationame': 'Loyola'}  2001-01-01T00:00:00
# 4  {'station_id': '40760', 'stationame': 'Granvil...  2001-01-01T00:00:00
# 5   {'station_id': '40850', 'stationame': 'Library'}  2020-09-01T00:00:00
# 6  {'station_id': '40680', 'stationame': 'Adams/W...  2020-09-01T00:00:00
# 7  {'station_id': '41700', 'stationame': 'Washing...  2020-09-01T00:00:00
# 8  {'station_id': '40260', 'stationame': 'State/L...  2020-09-01T00:00:00
# 9  {'station_id': '40380', 'stationame': 'Clark/L...  2020-09-01T00:00:00
#
#                                                rides
# 0  {'avg_weekday_rides': '6233.9', 'avg_saturday_...
# 1  {'avg_weekday_rides': '1489.1', 'avg_saturday_...
# 2  {'avg_weekday_rides': '4412.5', 'avg_saturday_...
# 3  {'avg_weekday_rides': '4664.5', 'avg_saturday_...
# 4  {'avg_weekday_rides': '3109.8', 'avg_saturday_...
# 5  {'avg_weekday_rides': '864.2', 'avg_saturday_r...
# 6  {'avg_weekday_rides': '1332.3', 'avg_saturday_...
# 7  {'avg_weekday_rides': '2707.4', 'avg_saturday_...
# 8  {'avg_weekday_rides': '2410', 'avg_saturday_ri...
# 9  {'avg_weekday_rides': '2949.6', 'avg_saturday_...

# %% [markdown]
# <h3><code>pandas.json_normalize()</code></h3>

# %%
with open('data/cta_monthly_l_rides_nested.json') as f:    
    jdata = json.load(f)
    
chi_month_rides_df = pd.json_normalize(jdata)

chi_month_rides_df
# Out:
#                  month station.station_id station.stationame  \
# 0  2001-01-01T00:00:00              40900             Howard
# 1  2001-01-01T00:00:00              41190             Jarvis
# 2  2001-01-01T00:00:00              40100              Morse
# 3  2001-01-01T00:00:00              41300             Loyola
# 4  2001-01-01T00:00:00              40760          Granville
# 5  2020-09-01T00:00:00              40850            Library
# 6  2020-09-01T00:00:00              40680       Adams/Wabash
# 7  2020-09-01T00:00:00              41700  Washington/Wabash
# 8  2020-09-01T00:00:00              40260         State/Lake
# 9  2020-09-01T00:00:00              40380         Clark/Lake
#
#   rides.avg_weekday_rides rides.avg_saturday_rides  \
# 0                  6233.9                   3814.5
# 1                  1489.1                     1054
# 2                  4412.5                   3064.5
# 3                  4664.5                     3156
# 4                  3109.8                     2126
# 5                   864.2                      534
# 6                  1332.3                    791.8
# 7                  2707.4                   1909.8
# 8                    2410                   2042.3
# 9                  2949.6                     1657
#
#   rides.avg_sunday_holiday_rides
# 0                         2408.6
# 1                            718
# 2                         2087.8
# 3                         1952.8
# 4                         1453.8
# 5                          417.2
# 6                          601.6
# 7                         1438.6
# 8                         1660.6
# 9                         1453.8

# %% [markdown]
# ## Merge Dictionaries in List Comprehension
#
# <h3><code>[{...}] + pandas.DataFrame()</code></h3>

# %%
with open('data/cta_monthly_l_rides_nested.json') as f:
    jdata = json.load(f)
    
print(type(jdata))
print(type(jdata[0]))
# Out:
# <class 'list'>
# <class 'dict'>

# %%
data = [{**j['station'], **{'month': j['month']}, **j['rides']} for j in jdata]

chi_month_rides_df = pd.DataFrame(data)

chi_month_rides_df
# Out:
#   station_id         stationame                month avg_weekday_rides  \
# 0      40900             Howard  2001-01-01T00:00:00            6233.9
# 1      41190             Jarvis  2001-01-01T00:00:00            1489.1
# 2      40100              Morse  2001-01-01T00:00:00            4412.5
# 3      41300             Loyola  2001-01-01T00:00:00            4664.5
# 4      40760          Granville  2001-01-01T00:00:00            3109.8
# 5      40850            Library  2020-09-01T00:00:00             864.2
# 6      40680       Adams/Wabash  2020-09-01T00:00:00            1332.3
# 7      41700  Washington/Wabash  2020-09-01T00:00:00            2707.4
# 8      40260         State/Lake  2020-09-01T00:00:00              2410
# 9      40380         Clark/Lake  2020-09-01T00:00:00            2949.6
#
#   avg_saturday_rides avg_sunday_holiday_rides
# 0             3814.5                   2408.6
# 1               1054                      718
# 2             3064.5                   2087.8
# 3               3156                   1952.8
# 4               2126                   1453.8
# 5                534                    417.2
# 6              791.8                    601.6
# 7             1909.8                   1438.6
# 8             2042.3                   1660.6
# 9               1657                   1453.8

# %% [markdown]
# <br/>
# <br/>
# <br/>
